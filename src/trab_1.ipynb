# %%
import oracledb

# %%
#Definindo creenciais de conexao

user = 'rm572248' 
pwd = '030189'
dsn = oracledb.makedsn('oracle.fiap.com.br', '1521', 'ORCL')

#Estabelecendo conexao
def conectar():
    con = oracledb.connect(user = user, password = pwd, dsn = dsn)
    return con
